# %% [markdown]
# # Assignment for Module 52446 - Fundamentals of Data Analysis
# ## Topic: Anscombe's quartet dataset

# %% [markdown]
# This assignment concerns the well-known Anscombe’s quartet dataset. I am required to create a Jupyter notebook analysing the dataset.
#
# ### 1.	Explain the background to the dataset – who created it, when it was created, and any speculation I can find regarding how it might have been created.
#
# While researching this subject I learned;
#
# *Anscombe's quartet comprises four datasets that have nearly identical simple descriptive statistics, yet appear very different when graphed.
# Each dataset consists of eleven (x,y) points.
# They were constructed in 1973 by the statistician Francis Anscombe to demonstrate both the importance of graphing data before analyzing it and the effect of outliers on statistical properties.
# He described the article as being intended to counter the impression among statisticians that "numerical calculations are exact, but graphs are rough."*
# Reference: https://en.wikipedia.org
#
# Image: https://en.wikipedia.org/wiki/Anscombe%27s_quartet#/media/File:Anscombe%27s_quartet_3.svg
#
# ![Image](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Anscombe%27s_quartet_3.svg/990px-Anscombe%27s_quartet_3.svg.png)
#
# In terms of speculation regarding how it might have been created, I discovered that;
# *It is not known how Anscombe created his datasets. Since its publication, several methods to generate similar data sets with identical statistics and dissimilar graphics have been developed.*
# (Reference: https://en.wikipedia.org)
#
# ![Image](http://brianmc.dbsdataprojects.com/wp-content/uploads/sites/56/2016/02/original-281x300.jpg)

# %% [markdown]
# ### 2.	Plot the interesting aspects of the dataset.
# Requirement: Do the plots in this Jupyter Notebook.

# %% [markdown]
# This dataset is interesting for the simple fact that although the plots on these graphs look different initially, the result is the same for all four plots.
#
# I revised the *Plotting in jupyter* video supplied by Dr. Ian McLoughlin on Moodle before attempting this task.
#
# During this video Ian mentioned that the ‘x’ axis should be in the left hand side square brackets, and the ‘y’ axis should be in the right hand side square brackets [].
#
# Ian used ‘import matplotlib.pyplot as plt’ in a Code cell in his Jupyter Notebook.
#
# I followed Ian’s example and inserted the numbers from the first section of *Anscombe’s quartet dataset* which I obtained online from Wikipedia. I then pressed ‘Shift’ and ‘Enter’ on my keyboard (as shown below), and the below result was produced in my Jupyter notebook;

# %% [markdown]
# #### Section 1 of the Dataset;

# %%
import matplotlib.pyplot as plt

# %%
plt.plot ([10,8,13,9,11,14,6,4,12,7,5], [8.04,6.95,7.58,8.81,8.33,9.96,7.24,4.26,10.84,4.82,5.68])

# %% [markdown]
# I followed the same steps for the remaining 3 sections and my results are shown below;

# %% [markdown]
# #### Section 2 of the Dataset:

# %%
import matplotlib.pyplot as plt

# %%
plt.plot ([10,8,13,9,11,14,6,4,12,7,5], [9.14,8.14,8.74,8.77,9.26,8.10,6.13,3.10,9.13,7.26,4.74])

# %% [markdown]
# #### Section 3 of the Dataset;

# %%
import matplotlib.pyplot as plt

# %%
plt.plot ([10,8,13,9,11,14,6,4,12,7,5], [7.46,6.77,12.74,7.11,7.81,8.84,6.08,5.39,8.15,6.42,5.73])

# %% [markdown]
# #### Section 4 of the Dataset;

# %%
import matplotlib.pyplot as plt

# %%
plt.plot ([8,8,8,8,8,8,8,19,8,8,8], [6.58,5.76,7.71,8.84,8.47,7.04,5.25,12.50,5.56,7.91,6.89])

# %% [markdown]
# I then decided to follow Ian’s example to display the plots as red dots so I could more easily compare them to the plots shown in the above image which is taken from the Anscombe's quartet Wikipedia page, so I inserted ‘r.’ ;

# %%
import matplotlib.pyplot as plt

# %%
plt.plot ([10,8,13,9,11,14,6,4,12,7,5], [8.04,6.95,7.58,8.81,8.33,9.96,7.24,4.26,10.84,4.82,5.68], 'r.')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot ([10,8,13,9,11,14,6,4,12,7,5], [9.14,8.14,8.74,8.77,9.26,8.10,6.13,3.10,9.13,7.26,4.74], 'r.')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot ([10,8,13,9,11,14,6,4,12,7,5], [7.46,6.77,12.74,7.11,7.81,8.84,6.08,5.39,8.15,6.42,5.73], 'r.')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot ([8,8,8,8,8,8,8,19,8,8,8], [6.58,5.76,7.71,8.84,8.47,7.04,5.25,12.50,5.56,7.91,6.89], 'r.')

# %% [markdown]
# I was happy to notice that when I compared the plots I had generated in my Notebook to those shown on the Anscombe's quartet Wikipedia page they were in sync. I knew I must be doing something right!

# %% [markdown]
# The interesting thing about this is that although not all the figures in the 4 sections of the dataset are the exact same, if one draws a straight line from the first point to the last (as shown in the first image in this Notebook) the same result is displayed for each one.
#
# -	*The first scatter plot (Section I of the Dataset) appears to be a simple linear relationship, corresponding to two variables correlated and following the assumption of normality.*
# -	*The second graph is not distributed normally; while a relationship between the two variables is obvious, it is not linear, and the Pearson correlation coefficient is not relevant. A more general regression and the corresponding coefficient of determination would be more appropriate.*
# -	*In the third graph, the distribution is linear, but should have a different regression line (a robust regression would have been called for). The calculated regression is offset by the one outlier which exerts enough influence to lower the correlation coefficient from 1 to 0.816.*
# -	*Finally, the fourth graph shows an example when one outlier is enough to produce a high correlation coefficient, even though the other data points do not indicate any relationship between the variables.*
#
# *The quartet is still often used to illustrate the importance of looking at a set of data graphically before starting to analyze according to a particular type of relationship, and the inadequacy of basic statistic properties for describing realistic datasets.*
#
# (Reference: https://en.wikipedia.org)

# %% [markdown]
# ### 3.	Calculate the descriptive statistics of the variables in the dataset.
# As we can see from the dataset, some plots vary hugely, and yet the same result is produced for all 4 sections.
#
# For example;
#
# Section I – 	First Plot: 10.0, 8.04
#                 Final Plot: 5.0, 5.68
#
# Section IV - 	First Plot: 8.0, 6.58
#                 Final Plot: 8.0, 6.89
#
# The first plots differ hugely;
#
# - 10.0 – 8.0 = 2
#
# - 8.04 – 6.58 = 1.46, etc.

# %% [markdown]
# ### 4.	Explain why the dataset is interesting, referring to the plots and statistics above.
#
# As we have calculated, some plots vary hugely, and yet the same result is produced for all 4 sections.
#
# *Anscombe’s quartet comprises four datasets that have nearly identical simple statistical properties, yet appear very different when graphed. Each dataset consists of eleven (x,y) points. They were constructed in 1973 by the statistician Francis Anscombe to demonstrate both the importance of graphing data before analyzing it and the effect of outliers on statistical properties.*
# (Reference: http://www.gettinggeneticsdone.com/2015/02/using-and-abusing-data-visualization.html)
#
# *All four sets are identical when examined using simple summary statistics, but vary considerably when graphed.*
# (Reference: Wikipedia)
#
# ##### References
# 1.	Wikipedia - https://en.wikipedia.org/wiki/Anscombe%27s_quartet
# 2.	Jupyter Notebook Tutorial - https://plot.ly/python/ipython-notebook-tutorial/
# 3.	GMIT Moodle – Videos supplied by Dr. Ian McLoughlin
# 4.	http://www.gettinggeneticsdone.com/2015/02/using-and-abusing-data-visualization.html
